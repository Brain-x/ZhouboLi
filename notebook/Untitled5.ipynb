# %%
import numpy as np
a=np.array([[[1,2,3],[4,'ae',6]],[[1,'ae',3],[4,4,6]]])
def find_array(ar,x):
    return np.array(np.nonzero(ar==x)).T
find_array(a,'ae')
# Out:
# array([[0, 1, 1],
#        [1, 0, 1]], dtype=int64)

# %%
import pandas as pd
dic={'黎洲波':[1,2],'施妙辉':[2,3],'孔繁梓':[4],'吕梦轩':[4,5]}

# %%
pd.DataFrame(dic,columns=dic,index=[2,5])
# Out:
#    黎洲波  施妙辉  孔繁梓  吕梦轩
# 2    1    2    4    4
# 5    2    3    4    5

# %%
f=pd.read_csv('2018.csv',sep=',',index_col=[0])
f
# Out:
#       性别  年龄          学校                学历  身高（单位：cm，例如：172）  体重（单位：kg，例如：60）  \
# 姓名
# 李莹莹    女  20    我是其他高校大佬    本科在读（或本科毕业已工作）               155             45.0
# 陈思思    女  20    我是其他高校大佬    本科在读（或本科毕业已工作）               160             50.0
# 钟梨     女  20    我是其他高校大佬    本科在读（或本科毕业已工作）               153             52.0
# 刘嵩     男  26      华中科技大学    博士在读（或博士毕业已工作）               183             88.0
# 小情绪    女  24      华中师范大学  研究生在读（或研究生毕业已工作）               161             59.0
# 吴川     男  22      华中科技大学  研究生在读（或研究生毕业已工作）               172             65.0
# 黄lh    男  20    我是其他高校大佬    本科在读（或本科毕业已工作）               177             60.0
# 刘雷     男  23      华中科技大学  研究生在读（或研究生毕业已工作）               175             64.0
# 闪闪繁星   男  22      华中师范大学    本科在读（或本科毕业已工作）               170             55.0
# 盖龄杰    男  19  中国地质大学（武汉）    本科在读（或本科毕业已工作）               180            150.0
# 林欣怡    男  20    我是其他高校大佬    本科在读（或本科毕业已工作）               168             52.0
# ...

# %%
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x,y=np.ogrid[-2:2:20j,-2:2:20j]
z=x*np.exp(-x**2-y**2)
ax.plot_surface(x, y, z)
